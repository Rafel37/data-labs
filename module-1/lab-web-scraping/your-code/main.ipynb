# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
html = requests.get(url)
soup = BeautifulSoup(html.text, "html.parser")
# soup

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

meta = soup.find_all("h1", {"class": "h3 lh-condensed"})
meta
text = [meta[i].find('a')['href'] for i in range(len(meta))]
pprint(text)
# Out:
# ['/saschagrunert',
#  '/williamFalcon',
#  '/haya14busa',
#  '/hajimehoshi',
#  '/swapagarwal',
#  '/liuchengxu',
#  '/gsantner',
#  '/me-no-dev',
#  '/purcell',
#  '/arvidn',
#  '/matchai',
#  '/borkdude',
#  '/chrisbanes',
#  '/TomasVotruba',
#  '/fatih',
#  '/alexcrichton',
#  '/streamich',
#  '/chriseth',
#  '/Andarist',
#  '/nhooyr',
#  '/iamareebjamal',
#  '/ericniebler',
#  '/frenck',
#  '/Ralith',
#  '/cmyr']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")


repositories_cont = soup.find_all('h1',{'class',"h3 lh-condensed"})


repositories = [repositories_cont[i].find('a')['href'] for i in range(len(repositories_cont))]
repositories
# Out:
# ['/streamlit/streamlit',
#  '/idealo/imagededup',
#  '/streamlit/demo-self-driving',
#  '/ytdl-org/youtube-dl',
#  '/arraiyopensource/kornia',
#  '/home-assistant/home-assistant',
#  '/scikit-learn/scikit-learn',
#  '/keras-team/keras',
#  '/astooke/rlpyt',
#  '/twintproject/twint',
#  '/fnplus/interview-techdev-guide',
#  '/facebookresearch/hydra',
#  '/metachar/PhoneSploit',
#  '/Yorko/mlcourse.ai',
#  '/swapagarwal/JARVIS-on-Messenger',
#  '/sphinx-doc/sphinx',
#  '/3b1b/manim',
#  '/0voice/interview_internal_reference',
#  '/Zhongdao/Towards-Realtime-MOT',
#  '/Tib3rius/AutoRecon',
#  '/google-research/football',
#  '/alicevision/meshroom',
#  '/trailofbits/algo',
#  '/Kr1s77/awesome-python-login-model',
#  '/joelgrus/data-science-from-scratch']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

images_cont = soup.find_all('img')

images = ["https:"+images.get('src') for images in images_cont]
images
# Out:
# ['https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 

#your code
html = requests.get(url).content
soup = BeautifulSoup(html)
links = []

links = soup.find_all('a')
links = [link.get('href') for link in links]
links
# Out:
# [None,
#  '#mw-head',
#  '#p-search',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '#Snakes',
#  '#Ancient_Greece',
#  '#Media_and_entertainment',
#  '#Computing',
#  '#Engineering',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#People',
#  '#Other_uses',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_(film)',
#  '/wiki/Pythons_2',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

#your code
html = requests.get(url).content
soup = BeautifulSoup(html)

titles = []

all_titles = soup.find_all('div', {'class', 'uscitem'})

for index, uscitem in enumerate(all_titles):
    if (index != 0 and uscitem.text.find('Appendix') == -1): 
        titles.append(uscitem.text.replace('\n','').replace('[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]','').replace('[XML]\xa0','').replace('116-21',''))
    
titles
# Out:
# ['          Title 1 - General Provisions ٭          116-59        ',
#  '          Title 2 - The Congress                  116-59        ',
#  '          Title 3 - The President ٭          116-59        ',
#  '          Title 4 - Flag and Seal, Seat of Government, and the States ٭          116-59        ',
#  '          Title 5 - Government Organization and Employees ٭          116-59        ',
#  '          Title 6 - Domestic Security                  116-59        ',
#  '          Title 7 - Agriculture                  116-59        ',
#  '          Title 8 - Aliens and Nationality                  116-59        ',
#  '          Title 9 - Arbitration ٭          116-59        ',
#  '          Title 10 - Armed Forces ٭          116-59        ',
#  '          Title 11 - Bankruptcy ٭          116-59        ',
#  '          Title 12 - Banks and Banking                  116-59        ',
#  '          Title 13 - Census ٭          116-59        ',
# ...

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

#your code 
html = requests.get(url).content
soup = BeautifulSoup(html)

wanted_names = soup.find_all('li', {'class', 'portal-type-person castle-grid-block-item'})

items = [lines.find('h3', {'class','title'}) for lines in wanted_names]
list_wanted = [wanted.text.replace('\n','') for wanted in items]

list_wanted
# Out:
# ['ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'
#your code
html = requests.get(url).content
soup = BeautifulSoup(html)
container = soup.find('tbody',{'id':'tbody'})
data = []
temp = []
jump = 0
earthquakes = container.find_all('td') 

for index,earthquake in enumerate(earthquakes):
    if(index == 3+jump):
        temp.append(earthquake.text[10:20])
        temp.append(earthquake.text[23:31])
    if(index == 4+jump):
        temp.append(earthquake.text.replace('\xa0',''))
    if(index == 6+jump):
        temp.append(earthquake.text.replace('\xa0',''))
    if(index == 11+jump):   
        temp.append(earthquake.text.replace('\xa0',''))
        jump+=13
        data.append(temp[0:5])
        temp = []

earthquake_df = pd.DataFrame(data, columns=['Date', 'Time', 'Latitude', 'Longitude', 'Region Name'])
earthquake_df.head(20)
# Out:
#           Date      Time Latitude Longitude                     Region Name
# 0   2019-10-09  12:03:36    19.19    155.45        ISLAND OF HAWAII, HAWAII
# 1   2019-10-09  11:38:57    19.18    155.44        ISLAND OF HAWAII, HAWAII
# 2   2019-10-09  11:38:13    37.94     35.25                  CENTRAL TURKEY
# 3   2019-10-09  11:28:43    33.02    116.36             SOUTHERN CALIFORNIA
# 4   2019-10-09  11:27:57    45.94     11.94                  NORTHERN ITALY
# 5   2019-10-09  11:24:48    37.29     20.56                      IONIAN SEA
# 6   2019-10-09  11:24:42    46.85    121.75  MOUNT RAINIER AREA, WASHINGTON
# 7   2019-10-09  10:49:14    15.42     94.31        OFFSHORE CHIAPAS, MEXICO
# 8   2019-10-09  10:44:35    36.50     70.64  HINDU KUSH REGION, AFGHANISTAN
# 9   2019-10-09  10:32:43    18.10     66.95                     PUERTO RICO
# 10  2019-10-09  10:00:11    17.76    178.70                     FIJI REGION
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'
url_raiz = 'https://hackevents.co'
#your code
html = requests.get(url).content
soup = BeautifulSoup(html)


data = []
links = []
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
containers = soup.find_all('a')


# loop to get the links for all events
for container in containers:
    if (container.get('href')[0:6] == '/event'):
        links.append(url_raiz + container.get('href'))

# loop to scrap every event page
for link in links:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find('div',{'class','row'})

    #title
    title = container.find('h2').text
    
    #the rest of the datums
    datums = container.find_all('p')
    
    city = datums[0].text.replace('\u2003 ','').split(',')[0]        
    country = datums[0].text.replace('\u2003 ','').split(',')[2] 
    start_date = datums[1].text.split(' ')[-1]
    start_day = int(start_date.split('/')[1])

    end_date = datums[2].text.split(' ')[-1] 
    end_day = int(end_date.split('/')[1])
    gape = end_day - start_day
    days = [start_day+day for day in range(gape+1)]
    
    data.append([start_day,days,title,city,country])

hackathons_df = pd.DataFrame(data, columns=['start_day', 'days', 'title', 'city', 'country'])
hackathons_df.head(25)
# Out:
#    start_day        days                           title    city   country
# 0          8  [8, 9, 10]  Oerlikon Digital Hub Hackathon  Munich   Germany

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

nick = input('Input your account name on Twitter: ')
temp = requests.get('https://twitter.com/' + nick)
bs = BeautifulSoup(temp.text,'lxml')

try:
    tweet_box = bs.find('li',{'class':'ProfileNav-item ProfileNav-item--tweets is-active'})
    tweets= tweet_box.find('a').find('span',{'class':'ProfileNav-value'})
    print("{} tweets {} number of tweets.".format(nick,tweets.get('data-count')))

except:
    print('Account name not found...')
# Out:
# Input your account name on Twitter: @yisucrist
# @yisucrist tweets 17000 number of tweets.

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
nick = input('Input your account name on Twitter: ') 
temp = requests.get('https://twitter.com/'+nick)
bs = BeautifulSoup(temp.text,'lxml')
try:
    follow_box = bs.find('li',{'class':'ProfileNav-item ProfileNav-item--followers'})
    followers = follow_box.find('a').find('span',{'class':'ProfileNav-value'})
    print("Number of followers: {} ".format(followers.get('data-count')))
except:
    print('Account name not found...')
# Out:
# Input your account name on Twitter: @rafa_perez37
# Number of followers: 134

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'
#your code
html = requests.get(url).content
soup = BeautifulSoup(html)

nameList = soup.findAll('a', {'class' : 'link-box'})
for name in nameList:
  print(name.get_text().replace('+',''))
# Out:
# English
# 5 944 000 articles
#
#
# Español
# 1 549 000 artículos
#
#
# 日本語
# 1 171 000 記事
#
#
# Deutsch
# 2 351 000 Artikel
#
#
# Русский
# 1 572 000 статей
#
#
# Français
# 2 144 000 articles
#
#
# Italiano
# 1 556 000 voci
#
#
# 中文
# 1 076 000 條目
#
#
# Português
# 1 014 000 artigos
#
#
# Polski
# 1 364 000 haseł

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html,  "html.parser")

meta = soup.find_all('h2')
text = [meta[i].find('a')['href'] for i in range(len(meta))]

ds_list = [ds.text.replace('\n','') for ds in meta]
ds_list
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'
#your code
html = requests.get(url).content
soup = BeautifulSoup(html)

table = soup.find('table',{'class':'wikitable sortable'})
links = table.findAll('a')

ds_list = [ds.text.replace('\n','') for ds in links]
ds_list
# Out:
# ['[7]',
#  'clarification needed',
#  '[a]',
#  '[8]',
#  'Mandarin',
#  '[9]',
#  'China',
#  'Sino-Tibetan',
#  'Sinitic',
#  'Spanish',
#  'Spain',
#  'Indo-European',
#  'Romance',
#  'English',
#  'United Kingdom',
#  'Indo-European',
#  'Germanic',
#  'Hindi',
#  '[10]',
#  'India',
#  'Indo-European',
#  'Indo-Aryan',
#  'Bengali',
#  'Bangladesh',
#  'Indo-European',
#  'Indo-Aryan',
#  'Portuguese',
#  'Portugal',
#  'Indo-European',
#  'Romance',
#  'Russian',
#  'Russian Federation',
#  'Indo-European',
#  'Balto-Slavic',
#  'Japanese',
#  'Japan',
#  'Japonic',
#  'Japanese',
#  'Western Punjabi',
#  '[11]',
#  'Pakistan',
#  'Indo-European',
#  'Indo-Aryan',
#  'Marathi',
#  'India',
#  'Indo-European',
#  'Indo-Aryan',
#  'Telugu',
#  'India',
#  'Dravidian',
#  'South-Central',
#  'Wu',
#  '[9]',
#  'China',
#  'Sino-Tibetan',
#  'Sinitic',
#  'Turkish',
#  'Turkey',
#  'Turkic',
#  'Oghuz',
#  'Korean',
#  'South Korea',
#  'Koreanic',
#  'language isolate',
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code
html = requests.get(url).content
soup = BeautifulSoup(html)

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
